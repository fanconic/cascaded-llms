# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/azureuser/caf83/cascaded-llms/results_neurips/run_20250730_200801_gen_mmlu_llama_1_8/results_gen_mmlu_llama_1_8_surrogate_token_probs_1_large.csv")

# %%
plt.hist(df.acceptance_ratios, bins=40)
# Out:
# (array([ 654.,  541.,  418.,  424.,  349.,  329.,  327.,  314.,  309.,
#          263.,  290.,  274.,  254.,  258.,  271.,  245.,  268.,  255.,
#          268.,  264.,  280.,  279.,  256.,  322.,  244.,  256.,  261.,
#          284.,  261.,  307.,  290.,  320.,  291.,  304.,  351.,  337.,
#          390.,  546.,  667., 1220.]),
#  array([2.81917630e-04, 2.52734496e-02, 5.02649816e-02, 7.52565136e-02,
#         1.00248046e-01, 1.25239578e-01, 1.50231110e-01, 1.75222641e-01,
#         2.00214173e-01, 2.25205705e-01, 2.50197237e-01, 2.75188769e-01,
#         3.00180301e-01, 3.25171833e-01, 3.50163365e-01, 3.75154897e-01,
#         4.00146429e-01, 4.25137961e-01, 4.50129493e-01, 4.75121025e-01,
#         5.00112557e-01, 5.25104089e-01, 5.50095621e-01, 5.75087153e-01,
#         6.00078685e-01, 6.25070217e-01, 6.50061749e-01, 6.75053281e-01,
#         7.00044813e-01, 7.25036345e-01, 7.50027877e-01, 7.75019409e-01,
#         8.00010941e-01, 8.25002473e-01, 8.49994005e-01, 8.74985537e-01,
# ...

# %%
plt.hist(df.base_prob, bins=40)
# Out:
# (array([1.300e+01, 8.000e+00, 2.100e+01, 6.000e+00, 6.000e+00, 1.000e+01,
#         1.400e+01, 1.000e+01, 8.000e+00, 1.100e+01, 1.400e+01, 1.100e+01,
#         1.000e+01, 1.200e+01, 1.500e+01, 1.600e+01, 1.500e+01, 1.900e+01,
#         1.700e+01, 2.100e+01, 1.800e+01, 1.500e+01, 1.100e+01, 2.200e+01,
#         2.300e+01, 1.500e+01, 2.600e+01, 2.800e+01, 2.500e+01, 3.400e+01,
#         3.200e+01, 3.700e+01, 4.400e+01, 7.400e+01, 1.190e+02, 1.740e+02,
#         3.870e+02, 8.240e+02, 2.273e+03, 9.603e+03]),
#  array([6.89991517e-04, 2.56711339e-02, 5.06522763e-02, 7.56334186e-02,
#         1.00614561e-01, 1.25595703e-01, 1.50576846e-01, 1.75557988e-01,
#         2.00539131e-01, 2.25520273e-01, 2.50501415e-01, 2.75482558e-01,
#         3.00463700e-01, 3.25444842e-01, 3.50425985e-01, 3.75407127e-01,
#         4.00388270e-01, 4.25369412e-01, 4.50350554e-01, 4.75331697e-01,
#         5.00312839e-01, 5.25293981e-01, 5.50275124e-01, 5.75256266e-01,
# ...

# %%
df.columns
# Out:
# Index(['question', 'decision', 'output', 'prediction', 'label',
#        'base_response', 'base_prediction', 'large_response',
#        'large_prediction', 'acceptance_ratios', 'M', 'u', 'base_prob',
#        'large_prob', 'uncertainty', 'base_uncertainty', 'large_uncertainty',
#        'tau_base', 'tau_large', 'cost', 'base_gen_cost', 'large_gen_cost',
#        'base_inf_cost', 'large_inf_cost', 'base_uncert_cost',
#        'large_uncert_cost', 'system_risk', 'system_risk_base',
#        'system_risk_large', 'system_risk_expert', 'system_risk_static',
#        'subject', 'level'],
#       dtype='object')
